# %% [markdown]
# # Foundation Data Sciences
# ## Week 03: Pandas - Data Wrangling

# %% [markdown]
# **Learning outcomes:**
# In this lab you will learn to prepare your data for future use. By the end of the lab you should be able to:
# - get an overview of your data,
# - clean data, and
# - combine data from multiple datasets.

# %% [markdown]
# After analysing the survival rate of different passenger groups on the titanic last week, now imagine you are a political advisor for the UN this week. You will analyse data from the World Health Organization (WHO), in order to answer the following question:
#
# **Research question:** Which medical, social and economic factors have the biggest impact on life expectancy, and which improvement would have the biggest impact on the three countries with the shortest life expectancy?
#
# **Data description:** The data from the first [dataset](https://www.kaggle.com/kumarajarshi/life-expectancy-who) for this lab originates from the Global Health Observatory (GHO) data repository under the WHO. It contains health factors, as well as social and economic data of 193 countries between 2000 and 2015. The dataset was slightly preprocessed for this lab. The [second dataset](https://data.world/fivethirtyeight/alcohol-consumption) is based on data from an article in 'Fivethirtyeight', a website that focuses on political and economic articles and polls. It contains information about the alcohol consumption in 193 countries.

# %% [markdown]
# **Remarks**
# - Starting from this lab, we will not provide all the code, but expect you to be able to draw from previous labs to fill in the code.
# - Try not to use copy+paste when coding these labs, as typing will help you memorize the code better.
# - Try to understand each detail in the code we provide, and read the comments!
# - In the text `df` refers to a generic pandas DataFrame, which allows us to indicate which methods are applied to DataFrames. E.g. in `df.head()`, the  `head` is a member function of a pandas DataFrame.
# - Finally, try to keep a **clean structure** when programming: As discussed in the previous lab, we will start by loading all libraries we need at the top of the lab.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# We can now start by loading the data we will use in this lab.
#
# **Exercise 01:**
#
# a) Load the `life_expectancy.csv` file which is in `datasets`, and store the variable as `life_expectancy`.
#
# b) Print the first few entries of the dataset.

# %%
# Your code
life_expectancy_filepath = os.path.join(os.getcwd(), 'datasets', 'life_expectancy.csv')
life_expectancy = pd.read_csv(life_expectancy_filepath)
life_expectancy.head()
print(life_expectancy)
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  percentage expenditure  Hepatitis B  Measles   BMI  ...  \
# 0                62               71.279624         65.0     1154  19.1  ...
# 1                64               73.523582         62.0      492  18.6  ...
# 2                66               73.219243         64.0      430  18.1  ...
# 3                69               78.184215         67.0     2787  17.6  ...
# 4                71                7.097109         68.0     3013  17.2  ...
# ...             ...                     ...          ...      ...   ...  ...
# 2933             27                0.000000         68.0       31  27.1  ...
# 2934             26                0.000000          7.0      998  26.7  ...
# 2935             25                0.000000         73.0      304  26.3  ...
# 2936             25                0.000000         76.0      529  25.9  ...
# 2937             24                0.000000         79.0     1483  25.5  ...
#
#       Polio  Total expenditure Diphtheria  HIV/AIDS         GDP  Population  \
# 0       6.0               8.16       65.0       0.1  584.259210  33736494.0
# 1      58.0               8.18       62.0       0.1  612.696514    327582.0
# 2      62.0               8.13       64.0       0.1  631.744976  31731688.0
# 3      67.0               8.52       67.0       0.1  669.959000   3696958.0
# 4      68.0               7.87       68.0       0.1   63.537231   2978599.0
# ...     ...                ...        ...       ...         ...         ...
# 2933   67.0               7.13       65.0      33.6  454.366654  12777511.0
# 2934    7.0               6.52       68.0      36.7  453.351155  12633897.0
# 2935   73.0               6.53       71.0      39.8   57.348340    125525.0
# 2936   76.0               6.16       75.0      42.1  548.587312  12366165.0
# 2937   78.0                7.1       78.0      43.5  547.358879  12222251.0
#
#       thinness 1-19 years  thinness 5-9 years  \
# 0                    17.2                17.3
# 1                    17.5                17.5
# 2                    17.7                17.7
# 3                    17.9                18.0
# 4                    18.2                18.2
# ...                   ...                 ...
# 2933                  9.4                 9.4
# 2934                  9.8                 9.9
# 2935                  1.2                 1.3
# 2936                  1.6                 1.7
# 2937                 11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 21 columns]

# %% [markdown]
# In the last lab you learned to load data, and get an overview of the data using `df.head()`. Now, we will look at higher level information of the data. Whenever you work with data, it is important to get a good idea of how your data looks like:
# - **Nature of data:** Is the data from a population (e.g. medical data from patients) or rather high-level statistics (e.g. economic data comparison of different countries)?
# - **Data format:** Is the dataset a relational database, if so what columns does it have?
# - **Missing data:** Is the data complete (e.g. does every row contain an entry in every column, or are some entries missing)?
# - **Consistent data:** Is the notation used consistent throughout the database (e.g. Nan vs None vs Null vs __ vs 0 vs -1 ...)?
#
# All those points and many more should be answered before you start running any algorithms on your data. **Clean data is key!**

# %% [markdown]
# ## 2.A Data exploration: High level information of DataFrames

# %% [markdown]
# In Exercise 01 you printed out the first few entries and also the column names. These entries might give you an idea of what type of entries you should expect in a specific columns. For example, in the column 'Total expenditure', which reflects the total general government expenditure on health, you should only expect numbers. However, this might not always be the case and the data might be stored in a different format from what you would expect. Columns with numbers could be floats, integers or even strings, e.g. 0 vs 0.0 vs 'Zero' vs 'NIL' vs '0'.
#
# **Exercise 02:** Use filtering to get all the entries for 'Zimbabwe'.

# %%
# Your code
Zimbabwe = life_expectancy[life_expectancy.Country == 'Zimbabwe']
Zimbabwe
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2922  Zimbabwe  2015  Developing             67.0            336.0
# 2923  Zimbabwe  2014  Developing             59.2            371.0
# 2924  Zimbabwe  2013  Developing             58.0            399.0
# 2925  Zimbabwe  2012  Developing             56.6            429.0
# 2926  Zimbabwe  2011  Developing             54.9            464.0
# 2927  Zimbabwe  2010  Developing             52.4            527.0
# 2928  Zimbabwe  2009  Developing             50.0            587.0
# 2929  Zimbabwe  2008  Developing             48.2            632.0
# 2930  Zimbabwe  2007  Developing             46.6             67.0
# 2931  Zimbabwe  2006  Developing             45.4              7.0
# 2932  Zimbabwe  2005  Developing             44.6            717.0
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  percentage expenditure  Hepatitis B  Measles   BMI  ...  \
# 2922             22                0.000000         87.0        0  31.8  ...
# 2923             23               10.822595         91.0        0  31.3  ...
# 2924             25               10.666707         95.0        0   3.8  ...
# 2925             26               92.602336         97.0        0   3.3  ...
# 2926             28               63.750530         94.0        0  29.9  ...
# 2927             29               53.308581          9.0     9696  29.4  ...
# 2928             30                1.040021         73.0      853  29.0  ...
# 2929             30               20.843429         75.0        0  28.6  ...
# 2930             29               29.814566         72.0      242  28.2  ...
# 2931             28               34.262169         68.0      212  27.9  ...
# 2932             28                8.717409         65.0      420  27.5  ...
# 2933             27                0.000000         68.0       31  27.1  ...
# 2934             26                0.000000          7.0      998  26.7  ...
# 2935             25                0.000000         73.0      304  26.3  ...
# 2936             25                0.000000         76.0      529  25.9  ...
# 2937             24                0.000000         79.0     1483  25.5  ...
#
#       Polio  Total expenditure Diphtheria  HIV/AIDS         GDP  Population  \
# 2922   88.0            No data       87.0       6.2  118.693830  15777451.0
# 2923   92.0               6.44       91.0       6.3  127.474620  15411675.0
# 2924   95.0               6.88       95.0       6.8  111.227396    155456.0
# 2925   95.0               6.69       95.0       8.8  955.648466   1471826.0
# 2926   93.0               6.31       93.0      13.3  839.927936  14386649.0
# 2927   89.0               5.37       89.0      15.7  713.635620   1486317.0
# 2928   69.0               6.26       73.0      18.1   65.824121   1381599.0
# 2929   75.0               4.96       75.0      20.5  325.678573  13558469.0
# 2930   73.0               4.47       73.0      23.7  396.998217   1332999.0
# 2931   71.0               5.12        7.0      26.8  414.796232  13124267.0
# 2932   69.0               6.44       68.0      30.3  444.765750    129432.0
# 2933   67.0               7.13       65.0      33.6  454.366654  12777511.0
# 2934    7.0               6.52       68.0      36.7  453.351155  12633897.0
# 2935   73.0               6.53       71.0      39.8   57.348340    125525.0
# 2936   76.0               6.16       75.0      42.1  548.587312  12366165.0
# 2937   78.0                7.1       78.0      43.5  547.358879  12222251.0
#
#       thinness 1-19 years  thinness 5-9 years  \
# 2922                  5.6                 5.5
# 2923                  5.9                 5.7
# 2924                  6.2                 6.0
# 2925                  6.5                 6.4
# 2926                  6.8                 6.7
# 2927                  7.1                 7.0
# 2928                  7.5                 7.4
# 2929                  7.8                 7.8
# 2930                  8.2                 8.2
# 2931                  8.6                 8.6
# 2932                  9.0                 9.0
# 2933                  9.4                 9.4
# 2934                  9.8                 9.9
# 2935                  1.2                 1.3
# 2936                  1.6                 1.7
# 2937                 11.0                11.2
#
#       Income composition of resources  Schooling
# 2922                            0.507       10.3
# 2923                            0.498       10.3
# 2924                            0.488       10.4
# 2925                            0.464        9.8
# 2926                            0.452       10.1
# 2927                            0.436       10.0
# 2928                            0.419        9.9
# 2929                            0.421        9.7
# 2930                            0.414        9.6
# 2931                            0.408        9.5
# 2932                            0.406        9.3
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [16 rows x 21 columns]

# %% [markdown]
#  As you can see it contains a string 'No data' in the 'Total expenditure' column. If we print out the entry below, which looks like a float (6.44), we realize something unexpected:

# %%
life_expectancy.iloc[2923]['Total expenditure']
# Out:
# '6.44'

# %% [markdown]
# It's printed out as '6.44' instead of 6.44. This is because pandas expects all entries in a specific column to be of the same type. Thus, when pandas loads the table from a csv file and finds an entry that clearly isn't a numeric value ('No data'), it casts all other entries in the same column to a string.
#
# To be certain of **what types are used** we can use `df.info()`.

# %%
life_expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9   BMI                              2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
#  12  Total expenditure                2938 non-null   object
#  13  Diphtheria                       2919 non-null   float64
#  14  HIV/AIDS                         2938 non-null   float64
#  15  GDP                              2490 non-null   float64
#  16  Population                       2286 non-null   float64
#  17  thinness 1-19 years              2904 non-null   float64
#  18  thinness 5-9 years               2904 non-null   float64
#  19  Income composition of resources  2771 non-null   float64
#  20  Schooling                        2775 non-null   float64
# dtypes: float64(14), int64(4), object(3)
# memory usage: 482.1+ KB

# %% [markdown]
# **Remark** The 'Total expenditure' column has `dtype:object`, but the entries we printed out above looked like strings. To understand why pandas stores strings as objects, read this answer on [stackoverflow](https://stackoverflow.com/questions/21018654/strings-in-a-dataframe-but-dtype-is-object/21020411). **Stackoverflow** is an extremely helpful website for most questions you will encounter when coding!

# %% [markdown]
# To get an **overview of the numerical data** you have in your dataset `.describe()` is a good option. It gives you the most important statistical analysis of your columns with numerical data.

# %%
life_expectancy.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#        percentage expenditure  Hepatitis B        Measles          BMI  \
# count             2938.000000  2385.000000    2938.000000  2904.000000
# mean               738.251295    80.940461    2419.592240    38.321247
# std               1987.914858    25.070016   11467.272489    20.044034
# min                  0.000000     1.000000       0.000000     1.000000
# 25%                  4.685343    77.000000       0.000000    19.300000
# 50%                 64.912906    92.000000      17.000000    43.500000
# 75%                441.534144    97.000000     360.250000    56.200000
# max              19479.911610    99.000000  212183.000000    87.300000
#
#        under-five deaths        Polio   Diphtheria     HIV/AIDS  \
# count        2938.000000  2919.000000  2919.000000  2938.000000
# mean           42.035739    82.550188    82.324084     1.742103
# std           160.445548    23.428046    23.716912     5.077785
# min             0.000000     3.000000     2.000000     0.100000
# 25%             0.000000    78.000000    78.000000     0.100000
# 50%             4.000000    93.000000    93.000000     0.100000
# 75%            28.000000    97.000000    97.000000     0.800000
# max          2500.000000    99.000000    99.000000    50.600000
#
#                  GDP    Population  thinness 1-19 years  thinness 5-9 years  \
# count    2490.000000  2.286000e+03          2904.000000         2904.000000
# mean     7483.158469  1.275338e+07             4.839704            4.870317
# std     14270.169342  6.101210e+07             4.420195            4.508882
# min         1.681350  3.400000e+01             0.100000            0.100000
# 25%       463.935626  1.957932e+05             1.600000            1.500000
# 50%      1766.947595  1.386542e+06             3.300000            3.300000
# 75%      5910.806335  7.420359e+06             7.200000            7.200000
# max    119172.741800  1.293859e+09            27.700000           28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# Have a look at the output of `df.describe()`.
#
# **Discussion 01:** Discuss with your lab partner what the `count` row represents. Check  the correct answer on stackoverflow or the official pandas documentation. How is this information helpful when analyzing your dataset? Use stackoverflow or the official documentation to work out how you could compute just one of the statistics for one specific column, e.g. how can we compute the mean of the 'BMI' column? Write down your answers:

# %% [markdown]
# Your answer:
# Count the non-null objects in each label

# %% [markdown]
# 'Total expenditure' is not listed in the statistical analysis, which is because, as mentioned above, all values were cast to a string when loaded. This is very annoying, as most values are actually numeric, and the statistical measures of the numeric values, such as the median, are still meaningful, even though not all values are numeric. To compute these values, we will have to clean up the data first. As mentioned above: **Clean data is key!**

# %% [markdown]
# ## 2.B Cleaning data

# %% [markdown]
# ### 2.B.1 Detecting non-numerical values

# %% [markdown]
# A common problem in datasets is that data are not consistently of the same type. For example, a date is written in a non-standard way or a number is given as a string instead of a numeric value. Many data analysis algorithms are applied to numeric data. So let's tackle the problem we encountered above in the 'Total expenditure' column.
#
# To help us ensure that every entry in a column is numeric, pandas offers the function `pd.to_numeric(series, errors={‘ignore’, ‘raise’, ‘coerce’}, downcast = {‘integer’, ‘signed’, ‘unsigned’, ‘float’})`.
#
# This function does three things:
# 1. it checks whether every entry is a numeric value
# 2. if a non-numeric value is encountered (error), either it is ignored, raised (see below) or replaced by a NaN value (`error = 'coerce'`)
# 3. if `downcast` is chosen (default is `None`), it casts all numeric values down to the specified parameter.
#
# **Remark:** If the chosen `dtype` occupies more bits  than the `dtype` of the value (e.g. chosen `dtype` is `float`, but the found value is `int`) `pd.to_numeric` doesn't recast the value!

# %%
life_expectancy['Total expenditure'] = pd.to_numeric(life_expectancy['Total expenditure'], 
                                                    errors = 'coerce')
life_expectancy['Total expenditure']
# Out:
# 0       8.16
# 1       8.18
# 2       8.13
# 3       8.52
# 4       7.87
#         ...
# 2933    7.13
# 2934    6.52
# 2935    6.53
# 2936    6.16
# 2937    7.10
# Name: Total expenditure, Length: 2938, dtype: float64

# %% [markdown]
# **Remark** `pd.numeric` creates a copy and does not apply the changes directly to the series, hence the need to save the changes as shown above. If you just want to check whether or not all values are numeric, you can call `pd.to_numeric(life_expectancy['Total expenditure'], errors='raise')`, which will raise errors but not save any changes.
#
# Why is it interesting to have NaN values instead of strings, such as 'No data'? Let's check the type.

# %%
type(np.NaN)
# Out:
# float

# %% [markdown]
# It's a float, which means that you can apply all numeric operations to entire columns; NaN values are usually just ignored. Now we can compute the missing values from our statistical analysis above.
#
# **Exercise 03:**
#
# a) Start by saving the values from the 'Total expenditure' column in a new variable `total_expenditure`. What type does `total_expenditure` have? (Try to think of the answer first, then check with `type()`.)
#
# b) Compute the eight values (count, mean, ...) using the methods you should have learned about in **Discussion 01**.

# %%
# Your code
total_expenditure = life_expectancy['Total expenditure']
print(type(total_expenditure))
total_expenditure.describe()
# Out:
# <class 'pandas.core.series.Series'>
# count    2712.00000
# mean        5.93819
# std         2.49832
# min         0.37000
# 25%         4.26000
# 50%         5.75500
# 75%         7.49250
# max        17.60000
# Name: Total expenditure, dtype: float64

# %% [markdown]
# **Remark:** By default, when loading a csv file in pandas, empty values are usually filled with *NaN values automatically*.
#
# However, even NaN values can be annoying. Where do you plot a value with x-coordinate 1 and y-coordinate NaN? There are different options for how to deal with NaN values.
#
# First, let's start by checking which values are NaN, using `.isna()`, which is a mask (we have discussed masks in lab01). It returns the same data structure as the one it is applied to, with `True` and `False` values instead of the values from the original data structure.

# %%
print('Series:\n')
print(life_expectancy['Life expectancy'].isna())
print('\n\nDataFrames:\n')
print(life_expectancy.isna())
# Out:
# Series:
#
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Name: Life expectancy, Length: 2938, dtype: bool
#
#
# DataFrames:
#
#       Country   Year  Status  Life expectancy  Adult Mortality  infant deaths  \
# 0       False  False   False            False            False          False
# 1       False  False   False            False            False          False
# 2       False  False   False            False            False          False
# 3       False  False   False            False            False          False
# 4       False  False   False            False            False          False
# ...       ...    ...     ...              ...              ...            ...
# 2933    False  False   False            False            False          False
# 2934    False  False   False            False            False          False
# 2935    False  False   False            False            False          False
# 2936    False  False   False            False            False          False
# 2937    False  False   False            False            False          False
#
#       percentage expenditure  Hepatitis B  Measles    BMI  ...  Polio  \
# 0                      False        False    False  False  ...  False
# 1                      False        False    False  False  ...  False
# 2                      False        False    False  False  ...  False
# 3                      False        False    False  False  ...  False
# 4                      False        False    False  False  ...  False
# ...                      ...          ...      ...    ...  ...    ...
# 2933                   False        False    False  False  ...  False
# 2934                   False        False    False  False  ...  False
# 2935                   False        False    False  False  ...  False
# 2936                   False        False    False  False  ...  False
# 2937                   False        False    False  False  ...  False
#
#       Total expenditure  Diphtheria  HIV/AIDS    GDP  Population  \
# 0                 False       False     False  False       False
# 1                 False       False     False  False       False
# 2                 False       False     False  False       False
# 3                 False       False     False  False       False
# 4                 False       False     False  False       False
# ...                 ...         ...       ...    ...         ...
# 2933              False       False     False  False       False
# 2934              False       False     False  False       False
# 2935              False       False     False  False       False
# 2936              False       False     False  False       False
# 2937              False       False     False  False       False
#
#       thinness 1-19 years  thinness 5-9 years  \
# 0                   False               False
# 1                   False               False
# 2                   False               False
# 3                   False               False
# 4                   False               False
# ...                   ...                 ...
# 2933                False               False
# 2934                False               False
# 2935                False               False
# 2936                False               False
# 2937                False               False
#
#       Income composition of resources  Schooling
# 0                               False      False
# 1                               False      False
# 2                               False      False
# 3                               False      False
# 4                               False      False
# ...                               ...        ...
# 2933                            False      False
# 2934                            False      False
# 2935                            False      False
# 2936                            False      False
# 2937                            False      False
#
# [2938 rows x 21 columns]

# %% [markdown]
# It looks like there are no NaN in the 'Life expectancy' column. Let's double check, by summing all the values of each column. (Remember that False == 0, and True == 1).

# %%
life_expectancy['Life expectancy'].isna().sum()
# Out:
# 10

# %% [markdown]
# It turns out that there are a few missing values, but none of them are at the beginning or the end, so we didn't see them. This is an **important lesson**: using `.head()` gives you a good initial idea of how the data looks like, but it is by no means comprehensive!
#
# ### 2.B.2 Working with NaN values
#
# #### Dropping NaN values
#
# Now we know how to find NaN values, let's fix those values. We have a couple of options. First, if you just want to get rid of data entries with NaN values, you can drop them using `.dropna(axis={0 or'index', 1 or'columns}, how={‘any’, ‘all’}, thresh=N, subset=[col1, col2, ...])`.

# %%
life_expectancy.dropna(axis = 0, how = 'any') # drops rows if any value is a NaN
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  percentage expenditure  Hepatitis B  Measles   BMI  ...  \
# 0                62               71.279624         65.0     1154  19.1  ...
# 1                64               73.523582         62.0      492  18.6  ...
# 2                66               73.219243         64.0      430  18.1  ...
# 3                69               78.184215         67.0     2787  17.6  ...
# 4                71                7.097109         68.0     3013  17.2  ...
# ...             ...                     ...          ...      ...   ...  ...
# 2933             27                0.000000         68.0       31  27.1  ...
# 2934             26                0.000000          7.0      998  26.7  ...
# 2935             25                0.000000         73.0      304  26.3  ...
# 2936             25                0.000000         76.0      529  25.9  ...
# 2937             24                0.000000         79.0     1483  25.5  ...
#
#       Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0       6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1      58.0               8.18        62.0       0.1  612.696514    327582.0
# 2      62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3      67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4      68.0               7.87        68.0       0.1   63.537231   2978599.0
# ...     ...                ...         ...       ...         ...         ...
# 2933   67.0               7.13        65.0      33.6  454.366654  12777511.0
# 2934    7.0               6.52        68.0      36.7  453.351155  12633897.0
# 2935   73.0               6.53        71.0      39.8   57.348340    125525.0
# 2936   76.0               6.16        75.0      42.1  548.587312  12366165.0
# 2937   78.0               7.10        78.0      43.5  547.358879  12222251.0
#
#       thinness 1-19 years  thinness 5-9 years  \
# 0                    17.2                17.3
# 1                    17.5                17.5
# 2                    17.7                17.7
# 3                    17.9                18.0
# 4                    18.2                18.2
# ...                   ...                 ...
# 2933                  9.4                 9.4
# 2934                  9.8                 9.9
# 2935                  1.2                 1.3
# 2936                  1.6                 1.7
# 2937                 11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1649 rows x 21 columns]

# %% [markdown]
# Because we specified `how='any'`, pandas drops a row if *any* column has a NaN value, so  the DataFrame is reduced to 1649 rows from 2938 rows initially. However, we wanted to discuss more ways of handling NaN values, and now we have dropped them. The good news is that  `dropna()` creates a copy, as usual with pandas DataFrame methods, and the original DataFrame is preserved. If you do want to apply those changes, you can use either `df = df.dropna(axis = 0, how = 'any')` or `df.dropna(axis = 0, how = 'any', inplace = True)`. `inplace=True` can be used in many DataFrame methods to apply the operations to the DataFrame.
#
# Now that we know that we didn't apply the changes to the DataFrame, let's discuss some more options for dealing with NaNs.
#
# Instead of `how = 'any'`, you can choose `'all'`, which drops rows only if *all* values are NaN. You can specify `axis=1`, to look along columns for NaN values and drop columns instead of rows. You can further set `subset=[col1, col2]` to search specific columns or rows for NaN values, and finally you can set a `thresh=N` to specify that at least `N` values need to be **non-NaN** to be kept. Give it a try!
#
# **Exercise 03:** Drop columns with more than 20% NaN values. Save the result to a new DataFrame and print that DataFrame.

# %%
# Your code
threshold = len(life_expectancy) - len(life_expectancy) // 5
life_expectancy.dropna(axis=1, thresh=threshold)
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  percentage expenditure  Hepatitis B  Measles   BMI  \
# 0                62               71.279624         65.0     1154  19.1
# 1                64               73.523582         62.0      492  18.6
# 2                66               73.219243         64.0      430  18.1
# 3                69               78.184215         67.0     2787  17.6
# 4                71                7.097109         68.0     3013  17.2
# ...             ...                     ...          ...      ...   ...
# 2933             27                0.000000         68.0       31  27.1
# 2934             26                0.000000          7.0      998  26.7
# 2935             25                0.000000         73.0      304  26.3
# 2936             25                0.000000         76.0      529  25.9
# 2937             24                0.000000         79.0     1483  25.5
#
#       under-five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0                    83    6.0               8.16        65.0       0.1
# 1                    86   58.0               8.18        62.0       0.1
# 2                    89   62.0               8.13        64.0       0.1
# 3                    93   67.0               8.52        67.0       0.1
# 4                    97   68.0               7.87        68.0       0.1
# ...                 ...    ...                ...         ...       ...
# 2933                 42   67.0               7.13        65.0      33.6
# 2934                 41    7.0               6.52        68.0      36.7
# 2935                 40   73.0               6.53        71.0      39.8
# 2936                 39   76.0               6.16        75.0      42.1
# 2937                 39   78.0               7.10        78.0      43.5
#
#              GDP  thinness 1-19 years  thinness 5-9 years  \
# 0     584.259210                 17.2                17.3
# 1     612.696514                 17.5                17.5
# 2     631.744976                 17.7                17.7
# 3     669.959000                 17.9                18.0
# 4      63.537231                 18.2                18.2
# ...          ...                  ...                 ...
# 2933  454.366654                  9.4                 9.4
# 2934  453.351155                  9.8                 9.9
# 2935   57.348340                  1.2                 1.3
# 2936  548.587312                  1.6                 1.7
# 2937  547.358879                 11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 20 columns]

# %% [markdown]
# You should have got the original DataFrame without the 'Population' column.
#
# #### Overwriting NaN values
# If you don't want to drop your data entries you can replace the values. You have many options, including:
# - The mean, max or min value of the column
# - strings
# - 0
#
# The function needed is `df.fillna(value={scalar, dict}, method={‘bfill’, ‘ffill’}, axis={0, 1}, limit=N)`.

# %%
life_expectancy.fillna(0).loc[2922] # Get row 2922 of the DataFrame where NaN values are replaced with 0.
# Out:
# Country                               Zimbabwe
# Year                                      2015
# Status                              Developing
# Life expectancy                             67
# Adult Mortality                            336
# infant deaths                               22
# percentage expenditure                       0
# Hepatitis B                                 87
# Measles                                      0
# BMI                                       31.8
# under-five deaths                           32
# Polio                                       88
# Total expenditure                            0
# Diphtheria                                  87
# HIV/AIDS                                   6.2
# GDP                                    118.694
# Population                         1.57775e+07
# thinness 1-19 years                        5.6
# thinness 5-9 years                         5.5
# Income composition of resources          0.507
# Schooling                                 10.3
# Name: 2922, dtype: object

# %% [markdown]
# Above we have applied two operations at once to the DataFrame. It shows the row we initially inspected where 'Total expenditure' = 'No data'. Now it is 0.
#
# **Remark:** In some cases, it makes more sense to replace different NaN values according to the column they are in. You can do this by passing a dictionary instead of a scalar. `df.fillna(value={'col1': value1, 'col2': value2})`. For more information on `fillna()` you are invited to check the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html).
#
# We will only be interested by entries with no NaN values for the rest of this lab, so we will drop all entries with NaN values:

# %%
life_expectancy.dropna(subset=['Life expectancy'], inplace=True)

# %% [markdown]
# ## 2.C Unique values

# %% [markdown]
# So far, we have loaded the data, we have extracted some high-level information about the data set, and dealt with missing data entries. These steps are important initial steps that need to be taken whenever you deal with data, especially data you haven't generated yourself.
#
# Another important step is to check whether your data is free of duplicate observations. Let's check how many unique values we have in each column of the DataFrame.

# %%
life_expectancy.nunique()
# Out:
# Country                             183
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# percentage expenditure             2323
# Hepatitis B                          87
# Measles                             958
# BMI                                 602
# under-five deaths                   252
# Polio                                73
# Total expenditure                   816
# Diphtheria                           81
# HIV/AIDS                            200
# GDP                                2485
# Population                         2277
# thinness 1-19 years                 200
# thinness 5-9 years                  207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %% [markdown]
# We see that, for example, in 'Status', we only have two unique values. Let's check which ones they are.

# %%
pd.unique(life_expectancy['Status'])
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %% [markdown]
# **Remark:** `df.nunique()` is applied to the data structure (Series or DataFrames), whereas `pd.unique()` takes the data structure as a parameter.
#
# The above query showed us that there are two categories in the 'Status' column: Developing and Developed. Let's find out the impact of whether a country is considered to be developing or developed.
#
# **Exercise 04:**
#
# a) Split the dataset into two subsets with the names 'developed' and 'developing' according to the status of the countries.
#
# b) Compute the mean life expectancy of each subset.

# %%
# Your code
developed = life_expectancy[life_expectancy.Status == 'Developed']
developing = life_expectancy[life_expectancy.Status == 'Developing']
print('developed mean:', developed.mean()['Life expectancy'])
print('developing mean:', developing.mean()['Life expectancy'])
# Out:
# developed mean: 79.19785156249996
# developing mean: 67.11146523178817

# %% [markdown]
# **Discussion:** Is the difference of life expectancy between the two groups about what you expected? If not what statistical metric could help you understand why the life expectancy difference is not what you expected? If you can think of a specific metric, compute that metric and see whether this confirms your expectations. Write down your answers:

# %% [markdown]
# Your answer:
# I expect the life expectancy for developed countries be higher than that of developing countries.

# %%
# Your code

# %% [markdown]
# We have found the unique values, but `pd.unique` searches unique values in each column. To search for entire rows of data that duplicate other rows, we need to use `df.duplicated(subset=[col1, col2, ...], keep={'first', 'last', False})`. This function is a mask; by now you should know how to use masks. It returns a Series with `True` and `False` entries, where `True` marks the rows that are duplicates of another row. The subset parameter allows you to specify which columns to consider when checking for duplicates. This can be very helpful when you have a column of unique identifiers, and you want to know if there are rows that are identical apart from the unique identifier. For example, different patients (with different IDs = unique identifier) might have the same symptoms. The `keep` parameter lets you specify which occurrence of a duplicate to mark as `False` (i.e. not as a duplicate):
# - `'first'`, which is the default value, marks the first occurrence as not a duplicate, but all other occurrences as duplicates of the first occurrence,
# - `'last'` marks the last occurrence as not a duplicate, but all other occurrences as duplicates of the last occurrence, and
# - `False` marks all occurrences of duplicates as duplicates.
#
# Let's give it a try:

# %%
life_expectancy.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Length: 2928, dtype: bool

# %% [markdown]
# As promised above, `.duplicated()` gives you a mask. It looks like no entry is a duplicate. Let's check.

# %%
life_expectancy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# (Remember, `False==0`, `True==1`; thus summing the series tells you how many `True` entries there were in the Series). The above tells you that there are no duplicates. Thankfully the WHO, as we would hope, created a clean dataset.
#
# Let's check whether there are countries in which the life expectancy remained the same over the years.

# %%
life_expectancy.duplicated(subset=['Country', 'Life expectancy']).sum()
# Out:
# 234

# %% [markdown]
# There are 136 instances in which the life expectancy did not change. Let's print them.
#
# **Exercise 05:**
# - Print *all* occurrences of duplicates. Hint: think about the keep parameter.
# - Print all the countries that appear in the list. Each country should only appear once.
# - Create a new DataFrame from the `life_expectancy` DataFrame, with the name `cleaned_life_expectancy`, in which  each country only appears once. Since the entries are sorted newest to oldest, only keep the newest observation of each country. Print out the first few lines to check your DataFrame looks as expected.
#
# **Hint:** to negate a condition in Pandas, use the tilde `~` operator instead of `not`, e.g.: if `people` is a DataFrame with a column `adult` of boolean values: `child = people[~people['adult']]`.

# %%
# Your code
# # Print all occurrences
pd.options.display.max_rows = None
np.set_printoptions(threshold=np.inf)
life_expectancy = pd.read_csv(life_expectancy_filepath)
duplicate = life_expectancy.duplicated(subset=['Country', 'Life expectancy'], keep=False)
for i in range(len(duplicate)):
    if duplicate.loc[i]:
        print(life_expectancy.loc[i])
        print()
countries = []
for i in range(len(duplicate)):
    if duplicate[i]:
        if not life_expectancy.loc[i]['Country'] in countries:
            countries.append(life_expectancy.loc[i]['Country'])
print(countries)
# Out:
# Country                            Afghanistan
# Year                                      2014
# Status                              Developing
# Life expectancy                           59.9
# Adult Mortality                            271
# infant deaths                               64
# percentage expenditure                 73.5236
# Hepatitis B                                 62
# Measles                                    492
# BMI                                       18.6
# under-five deaths                           86
# Polio                                       58
# Total expenditure                         8.18
# Diphtheria                                  62
# HIV/AIDS                                   0.1
# GDP                                    612.697
# Population                              327582
# thinness 1-19 years                       17.5
# thinness 5-9 years                        17.5
# Income composition of resources          0.476
# Schooling                                   10
# Name: 1, dtype: object
#
# Country                            Afghanistan
# Year                                      2013
# Status                              Developing
# Life expectancy                           59.9
# Adult Mortality                            268
# infant deaths                               66
# percentage expenditure                 73.2192
# Hepatitis B                                 64
# Measles                                    430
# BMI                                       18.1
# under-five deaths                           89
# Polio                                       62
# Total expenditure                         8.13
# Diphtheria                                  64
# HIV/AIDS                                   0.1
# GDP                                    631.745
# Population                         3.17317e+07
# thinness 1-19 years                       17.7
# thinness 5-9 years                        17.7
# Income composition of resources           0.47
# Schooling                                  9.9
# Name: 2, dtype: object
#
# Country                            Afghanistan
# Year                                      2006
# Status                              Developing
# Life expectancy                           57.3
# Adult Mortality                            295
# infant deaths                               84
# percentage expenditure                 17.1715
# Hepatitis B                                 64
# Measles                                   1990
# BMI                                       14.7
# under-five deaths                          116
# Polio                                       58
# Total expenditure                         7.43
# Diphtheria                                  58
# HIV/AIDS                                   0.1
# GDP                                    272.564
# Population                         2.58934e+06
# thinness 1-19 years                       19.2
# thinness 5-9 years                        19.3
# Income composition of resources          0.405
# Schooling                                  8.1
# Name: 9, dtype: object
#
# Country                            Afghanistan
# Year                                      2005
# Status                              Developing
# Life expectancy                           57.3
# Adult Mortality                            291
# infant deaths                               85
# percentage expenditure                 1.38865
# Hepatitis B                                 66
# Measles                                   1296
# BMI                                       14.2
# under-five deaths                          118
# Polio                                       58
# Total expenditure                          8.7
# Diphtheria                                  58
# HIV/AIDS                                   0.1
# GDP                                    25.2941
# Population                              257798
# thinness 1-19 years                       19.3
# thinness 5-9 years                        19.5
# Income composition of resources          0.396
# Schooling                                  7.9
# Name: 10, dtype: object
#
# Country                              Argentina
# Year                                      2003
# Status                              Developing
# Life expectancy                           74.1
# Adult Mortality                            137
# infant deaths                               11
# percentage expenditure                 57.5847
# Hepatitis B                                 73
# Measles                                      0
# BMI                                       55.7
# under-five deaths                           13
# Polio                                       95
# Total expenditure                         8.22
# Diphtheria                                  96
# HIV/AIDS                                   0.1
# GDP                                    333.438
# Population                         3.83938e+06
# thinness 1-19 years                        1.2
# thinness 5-9 years                           1
# Income composition of resources           0.77
# Schooling                                 16.4
# Name: 92, dtype: object
#
# Country                              Argentina
# Year                                      2002
# Status                              Developing
# Life expectancy                           74.1
# Adult Mortality                            138
# infant deaths                               12
# percentage expenditure                 470.187
# Hepatitis B                                 66
# Measles                                      0
# BMI                                       55.1
# under-five deaths                           13
# Polio                                       94
# Total expenditure                         8.31
# Diphtheria                                  93
# HIV/AIDS                                   0.1
# GDP                                    2579.19
# Population                         3.78894e+06
# thinness 1-19 years                        1.2
# thinness 5-9 years                           1
# Income composition of resources          0.776
# Schooling                                 16.3
# Name: 93, dtype: object
#
# Country                              Argentina
# Year                                      2000
# Status                              Developing
# Life expectancy                           74.1
# Adult Mortality                            137
# infant deaths                               12
# percentage expenditure                 1349.03
# Hepatitis B                                NaN
# Measles                                      6
# BMI                                         54
# under-five deaths                           14
# Polio                                       88
# Total expenditure                         9.21
# Diphtheria                                  83
# HIV/AIDS                                   0.1
# GDP                                    7669.27
# Population                         3.75745e+06
# thinness 1-19 years                        1.2
# thinness 5-9 years                         1.1
# Income composition of resources          0.764
# Schooling                                   15
# Name: 95, dtype: object
#
# Country                               Armenia
# Year                                     2013
# Status                             Developing
# Life expectancy                          74.4
# Adult Mortality                           123
# infant deaths                               1
# percentage expenditure                279.429
# Hepatitis B                                95
# Measles                                    10
# BMI                                      53.3
# under-five deaths                           1
# Polio                                      96
# Total expenditure                        4.55
# Diphtheria                                 95
# HIV/AIDS                                  0.1
# GDP                                   3843.59
# Population                             289359
# thinness 1-19 years                       2.1
# thinness 5-9 years                        2.1
# Income composition of resources         0.736
# Schooling                                12.7
# Name: 98, dtype: object
#
# Country                                Armenia
# Year                                      2012
# Status                              Developing
# Life expectancy                           74.4
# Adult Mortality                            121
# infant deaths                                1
# percentage expenditure                 274.153
# Hepatitis B                                 95
# Measles                                      0
# BMI                                       52.6
# under-five deaths                            1
# Polio                                       96
# Total expenditure                         4.48
# Diphtheria                                  95
# HIV/AIDS                                   0.1
# GDP                                    3684.85
# Population                         2.88192e+06
# thinness 1-19 years                          2
# thinness 5-9 years                         2.1
# Income composition of resources          0.732
# Schooling                                 12.7
# Name: 99, dtype: object
#
# Country                                Armenia
# Year                                      2010
# Status                              Developing
# Life expectancy                           73.5
# Adult Mortality                            132
# infant deaths                                1
# percentage expenditure                 224.321
# Hepatitis B                                 94
# Measles                                      2
# BMI                                       51.2
# under-five deaths                            1
# Polio                                       96
# Total expenditure                         4.56
# Diphtheria                                  94
# HIV/AIDS                                   0.1
# GDP                                    3218.38
# Population                         2.87731e+06
# thinness 1-19 years                          2
# thinness 5-9 years                         2.1
# Income composition of resources           0.72
# Schooling                                 12.3
# Name: 101, dtype: object
#
# Country                               Armenia
# Year                                     2007
# Status                             Developing
# Life expectancy                          73.5
# Adult Mortality                           132
# infant deaths                               1
# percentage expenditure                44.5722
# Hepatitis B                                85
# Measles                                     1
# BMI                                      49.7
# under-five deaths                           1
# Polio                                       9
# Total expenditure                        4.31
# Diphtheria                                 88
# HIV/AIDS                                  0.1
# GDP                                   3138.89
# Population                             293356
# thinness 1-19 years                         2
# thinness 5-9 years                        2.1
# Income composition of resources         0.707
# Schooling                                11.7
# Name: 104, dtype: object
#
# Country                                Armenia
# Year                                      2005
# Status                              Developing
# Life expectancy                             73
# Adult Mortality                            137
# infant deaths                                1
# percentage expenditure                 20.2182
# Hepatitis B                                 91
# Measles                                   2281
# BMI                                       48.8
# under-five deaths                            1
# Polio                                       92
# Total expenditure                         5.25
# Diphtheria                                   9
# HIV/AIDS                                   0.1
# GDP                                    1643.76
# Population                         2.98126e+06
# thinness 1-19 years                          2
# thinness 5-9 years                         2.1
# Income composition of resources          0.679
# Schooling                                 10.9
# Name: 106, dtype: object
#
# Country                               Armenia
# Year                                     2004
# Status                             Developing
# Life expectancy                            73
# Adult Mortality                           132
# infant deaths                               1
# percentage expenditure                97.7409
# Hepatitis B                                91
# Measles                                  1783
# BMI                                      48.4
# under-five deaths                           1
# Polio                                      93
# Total expenditure                         5.5
# Diphtheria                                 91
# HIV/AIDS                                  0.1
# GDP                                   1191.96
# Population                               3612
# thinness 1-19 years                         2
# thinness 5-9 years                        2.1
# Income composition of resources         0.668
# Schooling                                10.9
# Name: 107, dtype: object
#
# Country                               Armenia
# Year                                     2002
# Status                             Developing
# Life expectancy                          72.6
# Adult Mortality                           134
# infant deaths                               1
# percentage expenditure                57.1781
# Hepatitis B                                91
# Measles                                    40
# BMI                                      47.8
# under-five deaths                           1
# Polio                                      96
# Total expenditure                         5.4
# Diphtheria                                 94
# HIV/AIDS                                  0.1
# GDP                                   783.262
# Population                             333897
# thinness 1-19 years                       2.1
# thinness 5-9 years                        2.1
# Income composition of resources         0.645
# Schooling                                10.8
# Name: 109, dtype: object
#
# Country                               Armenia
# Year                                     2001
# Status                             Developing
# Life expectancy                          72.6
# Adult Mortality                           141
# infant deaths                               1
# percentage expenditure                53.1937
# Hepatitis B                                69
# Measles                                    69
# BMI                                      47.4
# under-five deaths                           1
# Polio                                      97
# Total expenditure                        5.94
# Diphtheria                                 94
# HIV/AIDS                                  0.1
# GDP                                   694.435
# Population                              35655
# thinness 1-19 years                       2.1
# thinness 5-9 years                        2.1
# Income composition of resources         0.644
# Schooling                                11.1
# Name: 110, dtype: object
#
# Country                            Australia
# Year                                    2008
# Status                             Developed
# Life expectancy                         81.3
# Adult Mortality                           66
# infant deaths                              1
# percentage expenditure               8547.29
# Hepatitis B                               94
# Measles                                   65
# BMI                                     62.9
# under-five deaths                          1
# Polio                                     92
# Total expenditure                       8.78
# Diphtheria                                92
# HIV/AIDS                                 0.1
# GDP                                  49664.7
# Population                            212492
# thinness 1-19 years                      0.7
# thinness 5-9 years                       0.6
# Income composition of resources        0.921
# Schooling                               19.1
# Name: 119, dtype: object
#
# Country                            Australia
# Year                                    2007
# Status                             Developed
# Life expectancy                         81.3
# Adult Mortality                           66
# infant deaths                              1
# percentage expenditure               872.599
# Hepatitis B                               94
# Measles                                   11
# BMI                                     62.5
# under-five deaths                          2
# Polio                                     92
# Total expenditure                       8.53
# Diphtheria                                92
# HIV/AIDS                                 0.1
# GDP                                  4991.98
# Population                             28276
# thinness 1-19 years                      0.7
# thinness 5-9 years                       0.6
# Income composition of resources        0.918
# Schooling                                 19
# Name: 120, dtype: object
#
# Country                            Australia
# Year                                    2002
# Status                             Developed
# Life expectancy                         79.9
# Adult Mortality                           73
# infant deaths                              1
# percentage expenditure               46.3872
# Hepatitis B                               95
# Measles                                   32
# BMI                                     59.6
# under-five deaths                          2
# Polio                                     92
# Total expenditure                       8.39
# Diphtheria                                92
# HIV/AIDS                                 0.1
# GDP                                  281.818
# Population                            196514
# thinness 1-19 years                      0.7
# thinness 5-9 years                       0.7
# Income composition of resources        0.902
# Schooling                               20.1
# Name: 125, dtype: object
#
# Country                            Australia
# Year                                    2001
# Status                             Developed
# Life expectancy                         79.9
# Adult Mortality                           75
# infant deaths                              1
# percentage expenditure                3064.3
# Hepatitis B                               94
# Measles                                  141
# BMI                                       59
# under-five deaths                          2
# Polio                                     91
# Total expenditure                       8.18
# Diphtheria                                92
# HIV/AIDS                                 0.1
# GDP                                  19517.8
# Population                             19413
# thinness 1-19 years                      0.7
# thinness 5-9 years                       0.7
# Income composition of resources        0.899
# Schooling                               20.5
# Name: 126, dtype: object
#
# Country                                Austria
# Year                                      2012
# Status                               Developed
# Life expectancy                             88
# Adult Mortality                              7
# infant deaths                                0
# percentage expenditure                 7878.37
# Hepatitis B                                 92
# Measles                                     36
# BMI                                       56.1
# under-five deaths                            0
# Polio                                       92
# Total expenditure                        11.17
# Diphtheria                                  92
# HIV/AIDS                                   0.1
# GDP                                    48333.6
# Population                         8.42999e+06
# thinness 1-19 years                        1.8
# thinness 5-9 years                           2
# Income composition of resources          0.884
# Schooling                                 15.7
# Name: 131, dtype: object
#
# Country                                Austria
# Year                                      2011
# Status                               Developed
# Life expectancy                             88
# Adult Mortality                             73
# infant deaths                                0
# percentage expenditure                 8272.31
# Hepatitis B                                 89
# Measles                                     68
# BMI                                       55.7
# under-five deaths                            0
# Polio                                       89
# Total expenditure                         1.94
# Diphtheria                                  89
# HIV/AIDS                                   0.1
# GDP                                    51126.7
# Population                         8.39164e+06
# thinness 1-19 years                        1.7
# thinness 5-9 years                           2
# Income composition of resources           0.88
# Schooling                                 15.7
# Name: 132, dtype: object
#
# Country                              Austria
# Year                                    2010
# Status                             Developed
# Life expectancy                           84
# Adult Mortality                           75
# infant deaths                              0
# percentage expenditure               7423.23
# Hepatitis B                               86
# Measles                                   52
# BMI                                     55.2
# under-five deaths                          0
# Polio                                     86
# Total expenditure                      11.17
# Diphtheria                                86
# HIV/AIDS                                 0.1
# GDP                                  46657.6
# Population                            836344
# thinness 1-19 years                      1.7
# thinness 5-9 years                       1.9
# Income composition of resources        0.872
# Schooling                               15.4
# Name: 133, dtype: object
#
# Country                               Austria
# Year                                     2008
# Status                              Developed
# Life expectancy                            84
# Adult Mortality                            76
# infant deaths                               0
# percentage expenditure                8329.73
# Hepatitis B                                83
# Measles                                   448
# BMI                                      54.2
# under-five deaths                           0
# Polio                                      83
# Total expenditure                         1.6
# Diphtheria                                 83
# HIV/AIDS                                  0.1
# GDP                                   51386.4
# Population                         8.3215e+06
# thinness 1-19 years                       1.7
# thinness 5-9 years                        1.9
# Income composition of resources         0.864
# Schooling                                15.1
# Name: 135, dtype: object
#
# Country                            Azerbaijan
# Year                                     2008
# Status                             Developing
# Life expectancy                            73
# Adult Mortality                           141
# infant deaths                               6
# percentage expenditure                206.262
# Hepatitis B                                68
# Measles                                     5
# BMI                                      46.6
# under-five deaths                           6
# Polio                                      85
# Total expenditure                        4.37
# Diphtheria                                 81
# HIV/AIDS                                  0.1
# GDP                                   5574.64
# Population                              87634
# thinness 1-19 years                       2.8
# thinness 5-9 years                        2.9
# Income composition of resources         0.719
# Schooling                                11.6
# Name: 151, dtype: object
#
# Country                            Azerbaijan
# Year                                     2007
# Status                             Developing
# Life expectancy                            73
# Adult Mortality                            14
# infant deaths                               6
# percentage expenditure                176.011
# Hepatitis B                                62
# Measles                                     0
# BMI                                      45.9
# under-five deaths                           7
# Polio                                      81
# Total expenditure                         5.1
# Diphtheria                                 79
# HIV/AIDS                                  0.1
# GDP                                   3851.44
# Population                              85813
# thinness 1-19 years                       2.8
# thinness 5-9 years                        2.9
# Income composition of resources         0.708
# Schooling                                11.6
# Name: 152, dtype: object
#
# Country                            Azerbaijan
# Year                                     2005
# Status                             Developing
# Life expectancy                          68.4
# Adult Mortality                           162
# infant deaths                               6
# percentage expenditure                81.2888
# Hepatitis B                                49
# Measles                                  1238
# BMI                                      44.7
# under-five deaths                           7
# Polio                                      79
# Total expenditure                        7.86
# Diphtheria                                 75
# HIV/AIDS                                  0.1
# GDP                                   1578.42
# Population                             839185
# thinness 1-19 years                       2.9
# thinness 5-9 years                          3
# Income composition of resources         0.675
# Schooling                                11.2
# Name: 154, dtype: object
#
# Country                            Azerbaijan
# Year                                     2004
# Status                             Developing
# Life expectancy                          68.4
# Adult Mortality                           154
# infant deaths                               6
# percentage expenditure                 8.5968
# Hepatitis B                                 5
# Measles                                   827
# BMI                                      44.2
# under-five deaths                           8
# Polio                                      78
# Total expenditure                        7.92
# Diphtheria                                 77
# HIV/AIDS                                  0.1
# GDP                                   145.216
# Population                               8365
# thinness 1-19 years                         3
# thinness 5-9 years                          3
# Income composition of resources         0.668
# Schooling                                  11
# Name: 155, dtype: object
#
# Country                            Azerbaijan
# Year                                     2003
# Status                             Developing
# Life expectancy                          67.8
# Adult Mortality                           154
# infant deaths                               7
# percentage expenditure                42.4149
# Hepatitis B                                51
# Measles                                  1978
# BMI                                      43.6
# under-five deaths                           8
# Polio                                      79
# Total expenditure                        6.56
# Diphtheria                                 77
# HIV/AIDS                                  0.1
# GDP                                   883.644
# Population                              82341
# thinness 1-19 years                         3
# thinness 5-9 years                          3
# Income composition of resources         0.659
# Schooling                                10.8
# Name: 156, dtype: object
#
# Country                            Azerbaijan
# Year                                     2002
# Status                             Developing
# Life expectancy                          67.8
# Adult Mortality                           146
# infant deaths                               7
# percentage expenditure                39.3325
# Hepatitis B                                 5
# Measles                                  4353
# BMI                                      43.1
# under-five deaths                           9
# Polio                                       8
# Total expenditure                        4.47
# Diphtheria                                 76
# HIV/AIDS                                  0.1
# GDP                                   763.739
# Population                             817195
# thinness 1-19 years                       3.1
# thinness 5-9 years                        3.1
# Income composition of resources         0.651
# Schooling                                10.6
# Name: 157, dtype: object
#
# Country                               Bahamas
# Year                                     2011
# Status                             Developing
# Life expectancy                            75
# Adult Mortality                           162
# infant deaths                               0
# percentage expenditure                      0
# Hepatitis B                                95
# Measles                                     0
# BMI                                        62
# under-five deaths                           0
# Polio                                      97
# Total expenditure                        7.63
# Diphtheria                                 98
# HIV/AIDS                                  0.1
# GDP                                       NaN
# Population                                NaN
# thinness 1-19 years                       2.5
# thinness 5-9 years                        2.5
# Income composition of resources         0.788
# Schooling                                12.6
# Name: 164, dtype: object
#
# Country                               Bahamas
# Year                                     2010
# Status                             Developing
# Life expectancy                            75
# Adult Mortality                           161
# infant deaths                               0
# percentage expenditure                      0
# Hepatitis B                                98
# Measles                                     0
# BMI                                      61.3
# under-five deaths                           0
# Polio                                      97
# Total expenditure                        7.44
# Diphtheria                                 99
# HIV/AIDS                                  0.2
# GDP                                       NaN
# Population                                NaN
# thinness 1-19 years                       2.5
# thinness 5-9 years                        2.5
# Income composition of resources         0.788
# Schooling                                12.6
# Name: 165, dtype: object
#
# Country                               Bahrain
# Year                                     2011
# Status                             Developing
# Life expectancy                          76.1
# Adult Mortality                            76
# infant deaths                               0
# percentage expenditure                197.773
# Hepatitis B                                99
# Measles                                     0
# BMI                                       6.8
# under-five deaths                           0
# Polio                                      99
# Total expenditure                         3.4
# Diphtheria                                 99
# HIV/AIDS                                  0.1
# GDP                                   2281.12
# Population                                NaN
# thinness 1-19 years                       6.1
# thinness 5-9 years                          6
# Income composition of resources         0.812
# Schooling                                14.4
# Name: 180, dtype: object
#
# Country                               Bahrain
# Year                                     2010
# Status                             Developing
# Life expectancy                          76.1
# Adult Mortality                            73
# infant deaths                               0
# percentage expenditure                 266.77
# Hepatitis B                                99
# Measles                                     0
# BMI                                       6.1
# under-five deaths                           0
# Polio                                      99
# Total expenditure                        3.64
# Diphtheria                                 99
# HIV/AIDS                                  0.1
# GDP                                   2722.14
# Population                                NaN
# thinness 1-19 years                         6
# thinness 5-9 years                        5.9
# Income composition of resources          0.81
# Schooling                                14.4
# Name: 181, dtype: object
#
# Country                                Belarus
# Year                                      2014
# Status                              Developing
# Life expectancy                             72
# Adult Mortality                            199
# infant deaths                                0
# percentage expenditure                 1147.11
# Hepatitis B                                 97
# Measles                                     64
# BMI                                       61.7
# under-five deaths                            0
# Polio                                       97
# Total expenditure                         5.69
# Diphtheria                                  97
# HIV/AIDS                                   0.1
# GDP                                    8318.43
# Population                         9.47451e+06
# thinness 1-19 years                        1.9
# thinness 5-9 years                           2
# Income composition of resources          0.796
# Schooling                                 15.7
# Name: 225, dtype: object
#
# Country                                Belarus
# Year                                      2011
# Status                              Developing
# Life expectancy                             72
# Adult Mortality                            232
# infant deaths                                0
# percentage expenditure                 846.911
# Hepatitis B                                 98
# Measles                                     50
# BMI                                       59.9
# under-five deaths                            1
# Polio                                       98
# Total expenditure                         4.92
# Diphtheria                                  98
# HIV/AIDS                                   0.1
# GDP                                    6519.72
# Population                         9.47317e+06
# thinness 1-19 years                          2
# thinness 5-9 years                         2.1
# Income composition of resources          0.787
# Schooling                                 15.5
# Name: 228, dtype: object
#
# Country                               Belarus
# Year                                     2009
# Status                             Developing
# Life expectancy                            70
# Adult Mortality                           226
# infant deaths                               0
# percentage expenditure                434.799
# Hepatitis B                                98
# Measles                                     0
# BMI                                      58.7
# under-five deaths                           1
# Polio                                      98
# Total expenditure                         6.9
# Diphtheria                                 96
# HIV/AIDS                                  0.1
# GDP                                   5176.17
# Population                             956765
# thinness 1-19 years                       2.1
# thinness 5-9 years                        2.2
# Income composition of resources         0.771
# Schooling                                15.4
# Name: 230, dtype: object
#
# Country                                Belarus
# Year                                      2008
# Status                              Developing
# Life expectancy                             70
# Adult Mortality                            224
# infant deaths                                1
# percentage expenditure                 501.806
# Hepatitis B                                 98
# Measles                                      0
# BMI                                       58.2
# under-five deaths                            1
# Polio                                       98
# Total expenditure                         5.95
# Diphtheria                                  97
# HIV/AIDS                                   0.1
# GDP                                    6376.18
# Population                         9.52798e+06
# thinness 1-19 years                        2.1
# thinness 5-9 years                         2.3
# Income composition of resources          0.755
# Schooling                                 15.1
# Name: 231, dtype: object
#
# Country                                Belarus
# Year                                      2003
# Status                              Developing
# Life expectancy                           67.7
# Adult Mortality                            253
# infant deaths                                1
# percentage expenditure                 23.8358
# Hepatitis B                                 56
# Measles                                     21
# BMI                                       55.8
# under-five deaths                            1
# Polio                                       53
# Total expenditure                         6.59
# Diphtheria                                   5
# HIV/AIDS                                   0.1
# GDP                                    1819.53
# Population                         9.79675e+06
# thinness 1-19 years                        2.5
# thinness 5-9 years                         2.6
# Income composition of resources          0.695
# Schooling                                 13.9
# Name: 236, dtype: object
#
# Country                                Belarus
# Year                                      2001
# Status                              Developing
# Life expectancy                           67.7
# Adult Mortality                            254
# infant deaths                                1
# percentage expenditure                 14.0614
# Hepatitis B                                 93
# Measles                                     45
# BMI                                       54.9
# under-five deaths                            1
# Polio                                       99
# Total expenditure                         6.62
# Diphtheria                                  99
# HIV/AIDS                                   0.1
# GDP                                    1244.37
# Population                         9.92855e+06
# thinness 1-19 years                        2.6
# thinness 5-9 years                         2.7
# Income composition of resources          0.681
# Schooling                                 13.3
# Name: 238, dtype: object
#
# Country                                Belgium
# Year                                      2012
# Status                               Developed
# Life expectancy                             83
# Adult Mortality                             78
# infant deaths                                0
# percentage expenditure                 664.474
# Hepatitis B                                 98
# Measles                                    109
# BMI                                       62.6
# under-five deaths                            1
# Polio                                       99
# Total expenditure                         1.54
# Diphtheria                                  99
# HIV/AIDS                                   0.1
# GDP                                    4474.57
# Population                         1.11282e+07
# thinness 1-19 years                        0.9
# thinness 5-9 years                         0.9
# Income composition of resources          0.886
# Schooling                                 16.2
# Name: 243, dtype: object
#
# Country                                Belgium
# Year                                      2011
# Status                               Developed
# Life expectancy                             83
# Adult Mortality                              8
# infant deaths                                0
# percentage expenditure                  713.53
# Hepatitis B                                 97
# Measles                                    576
# BMI                                       62.3
# under-five deaths                            1
# Polio                                       98
# Total expenditure                         1.42
# Diphtheria                                  98
# HIV/AIDS                                   0.1
# GDP                                    4772.77
# Population                         1.14774e+06
# thinness 1-19 years                        0.9
# thinness 5-9 years                         0.9
# Income composition of resources          0.884
# Schooling                                 16.1
# Name: 244, dtype: object
#
# Country                              Belgium
# Year                                    2008
# Status                             Developed
# Life expectancy                         79.5
# Adult Mortality                           87
# infant deaths                              0
# percentage expenditure               7191.05
# Hepatitis B                               98
# Measles                                   98
# BMI                                     61.3
# under-five deaths                          1
# Polio                                     99
# Total expenditure                        9.6
# Diphtheria                                99
# HIV/AIDS                                 0.1
# GDP                                  48424.6
# Population                            179973
# thinness 1-19 years                      0.8
# thinness 5-9 years                       0.8
# Income composition of resources        0.874
# Schooling                               15.8
# Name: 247, dtype: object
#
# Country                              Belgium
# Year                                    2007
# Status                             Developed
# Life expectancy                         79.5
# Adult Mortality                           86
# infant deaths                              0
# percentage expenditure               640.356
# Hepatitis B                               94
# Measles                                   64
# BMI                                      6.9
# under-five deaths                          1
# Polio                                     99
# Total expenditure                       9.25
# Diphtheria                                98
# HIV/AIDS                                 0.1
# GDP                                  4443.83
# Population                             16257
# thinness 1-19 years                      0.8
# thinness 5-9 years                       0.8
# Income composition of resources        0.871
# Schooling                               15.8
# Name: 248, dtype: object
#
# Country                                Belgium
# Year                                      2002
# Status                               Developed
# Life expectancy                             78
# Adult Mortality                             99
# infant deaths                                1
# percentage expenditure                 320.318
# Hepatitis B                                  6
# Measles                                      0
# BMI                                         59
# under-five deaths                            1
# Polio                                       96
# Total expenditure                         8.46
# Diphtheria                                  95
# HIV/AIDS                                   0.1
# GDP                                    2552.33
# Population                         1.33278e+06
# thinness 1-19 years                        0.8
# thinness 5-9 years                         0.8
# Income composition of resources          0.875
# Schooling                                 18.8
# Name: 253, dtype: object
#
# Country                              Belgium
# Year                                    2001
# Status                             Developed
# Life expectancy                           78
# Adult Mortality                            1
# infant deaths                              1
# percentage expenditure               2943.38
# Hepatitis B                                6
# Measles                                   83
# BMI                                     58.5
# under-five deaths                          1
# Polio                                     96
# Total expenditure                       8.29
# Diphtheria                                95
# HIV/AIDS                                 0.1
# GDP                                  23121.6
# Population                            128657
# thinness 1-19 years                      0.8
# thinness 5-9 years                       0.8
# Income composition of resources        0.873
# Schooling                               18.2
# Name: 254, dtype: object
#
# Country                                Belize
# Year                                     2012
# Status                             Developing
# Life expectancy                          69.4
# Adult Mortality                           189
# infant deaths                               0
# percentage expenditure                582.803
# Hepatitis B                                98
# Measles                                     0
# BMI                                      48.5
# under-five deaths                           0
# Polio                                      98
# Total expenditure                        5.45
# Diphtheria                                 98
# HIV/AIDS                                  0.1
# GDP                                   4673.64
# Population                              33671
# thinness 1-19 years                       3.5
# thinness 5-9 years                        3.4
# Income composition of resources         0.702
# Schooling                                12.5
# Name: 259, dtype: object
#
# Country                                Belize
# Year                                     2011
# Status                             Developing
# Life expectancy                          69.4
# Adult Mortality                           188
# infant deaths                               0
# percentage expenditure                605.629
# Hepatitis B                                95
# Measles                                     0
# BMI                                      47.8
# under-five deaths                           0
# Polio                                      95
# Total expenditure                        5.61
# Diphtheria                                 95
# HIV/AIDS                                  0.5
# GDP                                   4516.25
# Population                             329192
# thinness 1-19 years                       3.5
# thinness 5-9 years                        3.4
# Income composition of resources           0.7
# Schooling                                12.4
# Name: 260, dtype: object
#
# Country                                Belize
# Year                                     2010
# Status                             Developing
# Life expectancy                          69.5
# Adult Mortality                           186
# infant deaths                               0
# percentage expenditure                569.953
# Hepatitis B                                96
# Measles                                     0
# BMI                                        47
# under-five deaths                           0
# Polio                                      96
# Total expenditure                        5.85
# Diphtheria                                 96
# HIV/AIDS                                  0.2
# GDP                                   4344.15
# Population                              32168
# thinness 1-19 years                       3.5
# thinness 5-9 years                        3.4
# Income composition of resources           0.7
# Schooling                                12.4
# Name: 261, dtype: object
#
# Country                                Belize
# Year                                     2009
# Status                             Developing
# ...
# Year                                                             2011
# Status                                                     Developing
# Life expectancy                                                  73.8
# Adult Mortality                                                   158
# infant deaths                                                       9
# percentage expenditure                                              0
# Hepatitis B                                                        78
# Measles                                                             0
# BMI                                                              59.9
# under-five deaths                                                  10
# Polio                                                              78
# Total expenditure                                                5.24
# Diphtheria                                                         78
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.6
# thinness 5-9 years                                                1.5
# Income composition of resources                                 0.756
# Schooling                                                        14.1
# Name: 2862, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2010
# Status                                                     Developing
# Life expectancy                                                  73.7
# Adult Mortality                                                   158
# infant deaths                                                       9
# percentage expenditure                                              0
# Hepatitis B                                                        78
# Measles                                                             0
# BMI                                                              59.3
# under-five deaths                                                  10
# Polio                                                              74
# Total expenditure                                                 5.4
# Diphtheria                                                         78
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.6
# thinness 5-9 years                                                1.5
# Income composition of resources                                 0.754
# Schooling                                                          14
# Name: 2863, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2009
# Status                                                     Developing
# Life expectancy                                                  73.6
# Adult Mortality                                                   166
# infant deaths                                                       9
# percentage expenditure                                              0
# Hepatitis B                                                        84
# Measles                                                             0
# BMI                                                              58.8
# under-five deaths                                                  10
# Polio                                                              75
# Total expenditure                                                5.81
# Diphtheria                                                         84
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.6
# thinness 5-9 years                                                1.5
# Income composition of resources                                 0.754
# Schooling                                                          14
# Name: 2864, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2006
# Status                                                     Developing
# Life expectancy                                                  73.6
# Adult Mortality                                                   163
# infant deaths                                                       9
# percentage expenditure                                              0
# Hepatitis B                                                        71
# Measles                                                            78
# BMI                                                              57.1
# under-five deaths                                                  11
# Polio                                                              73
# Total expenditure                                                4.85
# Diphtheria                                                         71
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.6
# thinness 5-9 years                                                1.6
# Income composition of resources                                 0.714
# Schooling                                                        12.4
# Name: 2867, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2005
# Status                                                     Developing
# Life expectancy                                                  73.6
# Adult Mortality                                                   158
# infant deaths                                                       9
# percentage expenditure                                              0
# Hepatitis B                                                        88
# Measles                                                             0
# BMI                                                              56.5
# under-five deaths                                                  11
# Polio                                                               8
# Total expenditure                                                4.69
# Diphtheria                                                         87
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.7
# thinness 5-9 years                                                1.6
# Income composition of resources                                   0.7
# Schooling                                                        11.8
# Name: 2868, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2001
# Status                                                     Developing
# Life expectancy                                                  72.5
# Adult Mortality                                                   169
# infant deaths                                                      10
# percentage expenditure                                              0
# Hepatitis B                                                        53
# Measles                                                           115
# BMI                                                              54.1
# under-five deaths                                                  12
# Polio                                                              87
# Total expenditure                                                5.21
# Diphtheria                                                          7
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.8
# thinness 5-9 years                                                1.7
# Income composition of resources                                 0.672
# Schooling                                                        10.4
# Name: 2872, dtype: object
#
# Country                            Venezuela (Bolivarian Republic of)
# Year                                                             2000
# Status                                                     Developing
# Life expectancy                                                  72.5
# Adult Mortality                                                   168
# infant deaths                                                      11
# percentage expenditure                                              0
# Hepatitis B                                                         5
# Measles                                                            22
# BMI                                                              53.4
# under-five deaths                                                  13
# Polio                                                              86
# Total expenditure                                                4.91
# Diphtheria                                                         77
# HIV/AIDS                                                          0.1
# GDP                                                               NaN
# Population                                                        NaN
# thinness 1-19 years                                               1.8
# thinness 5-9 years                                                1.7
# Income composition of resources                                  0.67
# Schooling                                                        10.6
# Name: 2873, dtype: object
#
# Country                                 Yemen
# Year                                     2014
# Status                             Developing
# Life expectancy                          65.4
# Adult Mortality                           228
# infant deaths                              37
# percentage expenditure                      0
# Hepatitis B                                73
# Measles                                   815
# BMI                                       4.4
# under-five deaths                          47
# Polio                                      67
# Total expenditure                        5.64
# Diphtheria                                 73
# HIV/AIDS                                  0.1
# GDP                                       NaN
# Population                                NaN
# thinness 1-19 years                      13.7
# thinness 5-9 years                       13.5
# Income composition of resources           0.5
# Schooling                                   9
# Name: 2891, dtype: object
#
# Country                                 Yemen
# Year                                     2013
# Status                             Developing
# Life expectancy                          65.4
# Adult Mortality                           226
# infant deaths                              36
# percentage expenditure                      0
# Hepatitis B                                73
# Measles                                   400
# BMI                                      39.6
# under-five deaths                          46
# Polio                                      67
# Total expenditure                        5.78
# Diphtheria                                 73
# HIV/AIDS                                  0.1
# GDP                                       NaN
# Population                                NaN
# thinness 1-19 years                      13.7
# thinness 5-9 years                       13.5
# Income composition of resources         0.498
# Schooling                                   9
# Name: 2892, dtype: object
#
# Country                                Zambia
# Year                                     2010
# Status                             Developing
# Life expectancy                            58
# Adult Mortality                           363
# infant deaths                              30
# percentage expenditure                184.365
# Hepatitis B                                83
# Measles                                 15754
# BMI                                       2.7
# under-five deaths                          45
# Polio                                       8
# Total expenditure                        4.41
# Diphtheria                                 83
# HIV/AIDS                                  6.8
# GDP                                   1463.21
# Population                             138533
# thinness 1-19 years                       6.7
# thinness 5-9 years                        6.5
# Income composition of resources         0.533
# Schooling                                11.8
# Name: 2911, dtype: object
#
# Country                                 Zambia
# Year                                      2006
# Status                              Developing
# Life expectancy                             58
# Adult Mortality                            526
# infant deaths                               33
# percentage expenditure                    1.86
# Hepatitis B                                 81
# Measles                                    459
# BMI                                       18.8
# under-five deaths                           52
# Polio                                       83
# Total expenditure                         6.11
# Diphtheria                                  81
# HIV/AIDS                                  15.9
# GDP                                    13.1542
# Population                         1.23834e+07
# thinness 1-19 years                          7
# thinness 5-9 years                         6.9
# Income composition of resources          0.479
# Schooling                                 10.9
# Name: 2915, dtype: object
# ['Afghanistan', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Belarus', 'Belgium', 'Belize', 'Bosnia and Herzegovina', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Canada', 'Central African Republic', 'Chad', 'Chile', 'Colombia', 'Comoros', 'Costa Rica', 'Croatia', 'Cuba', "Democratic People's Republic of Korea", 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'France', 'Gabon', 'Georgia', 'Germany', 'Guinea', 'Guyana', 'Haiti', 'Hungary', 'Iceland', 'Iraq', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Libya', 'Lithuania', 'Mali', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia (Federated States of)', 'Mongolia', 'Montenegro', 'Mozambique', 'Namibia', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger', 'Norway', 'Panama', 'Peru', 'Philippines', 'Qatar', 'Republic of Moldova', 'Romania', 'Russian Federation', 'Saint Vincent and the Grenadines', 'Samoa', 'Saudi Arabia', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Solomon Islands', 'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan', 'The former Yugoslav republic of Macedonia', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkmenistan', 'Ukraine', 'United Kingdom of Great Britain and Northern Ireland', 'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)', 'Yemen', 'Zambia']

# %%
cleaned_life_expectancy = pd.DataFrame(columns=life_expectancy.columns)
i = 0
for country in countries:
    country_list = life_expectancy[life_expectancy.Country == country]
    cleaned_life_expectancy.loc[i] = list(country_list.iloc[0])
    i += 1
cleaned_life_expectancy
# Out:
#                                 Country  Year      Status  Life expectancy  \
# 0                           Afghanistan  2015  Developing             65.0
# 1                             Argentina  2015  Developing             76.3
# 2                               Armenia  2015  Developing             74.8
# 3                             Australia  2015   Developed             82.8
# 4                               Austria  2015   Developed             81.5
# ..                                  ...   ...         ...              ...
# 105                          Uzbekistan  2015  Developing             69.4
# 106                             Vanuatu  2015  Developing             72.0
# 107  Venezuela (Bolivarian Republic of)  2015  Developing             74.1
# 108                               Yemen  2015  Developing             65.7
# 109                              Zambia  2015  Developing             61.8
#
#      Adult Mortality infant deaths  percentage expenditure  Hepatitis B  \
# 0              263.0            62               71.279624         65.0
# 1              116.0             8                0.000000         94.0
# 2              118.0             1                0.000000         94.0
# 3               59.0             1                0.000000         93.0
# 4               65.0             0                0.000000         93.0
# ..               ...           ...                     ...          ...
# 105            184.0            15                0.000000         99.0
# 106             13.0             0                0.000000         64.0
# 107            157.0             9                0.000000         87.0
# 108            224.0            37                0.000000         69.0
# 109             33.0            27                0.000000          9.0
#
#     Measles   BMI  ... Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0      1154  19.1  ...   6.0               8.16        65.0       0.1
# 1         0  62.8  ...  93.0                NaN        94.0       0.1
# 2        33  54.9  ...  96.0                NaN        94.0       0.1
# 3        74  66.6  ...  93.0                NaN        93.0       0.1
# 4       309  57.6  ...  93.0                NaN        93.0       0.1
# ..      ...   ...  ...   ...                ...         ...       ...
# 105      22  44.7  ...  99.0                NaN        99.0       0.1
# 106      39  53.3  ...  65.0                NaN        64.0       0.1
# 107       0  62.1  ...  87.0                NaN        87.0       0.1
# 108     468  41.3  ...  63.0                NaN        69.0       0.1
# 109       9  23.4  ...   9.0                NaN         9.0       4.1
#
#               GDP  Population  thinness 1-19 years  thinness 5-9 years  \
# 0      584.259210  33736494.0                 17.2                17.3
# 1    13467.123600  43417765.0                  1.0                 0.9
# 2      369.654776    291695.0                  2.1                 2.2
# 3    56554.387600  23789338.0                  0.6                 0.6
# 4    43665.947000   8633169.0                  1.9                 2.1
# ..            ...         ...                  ...                 ...
# 105   2137.576852    312989.0                  3.0                 3.1
# 106    285.834140     26463.0                  1.5                 1.4
# 107           NaN         NaN                  1.6                 1.5
# 108           NaN         NaN                 13.6                13.4
# 109   1313.889646    161587.0                  6.3                 6.1
#
#      Income composition of resources  Schooling
# 0                              0.479       10.1
# 1                              0.826       17.3
# 2                              0.741       12.7
# 3                              0.937       20.4
# 4                              0.892       15.9
# ..                               ...        ...
# 105                            0.697       12.1
# 106                            0.598       10.8
# 107                            0.769       14.3
# 108                            0.499        9.0
# 109                            0.576       12.5
#
# [110 rows x 21 columns]

# %% [markdown]
# We have finished cleaning our dataset. Let's plot some of the results. You can ignore the code below; we will learn about plotting in the next two labs and this is just to give you an idea of your data.

# %%
cleaned_life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1    Argentina  2015  Developing             76.3            116.0
# 2      Armenia  2015  Developing             74.8            118.0
# 3    Australia  2015   Developed             82.8             59.0
# 4      Austria  2015   Developed             81.5             65.0
#
#   infant deaths  percentage expenditure  Hepatitis B Measles   BMI  ... Polio  \
# 0            62               71.279624         65.0    1154  19.1  ...   6.0
# 1             8                0.000000         94.0       0  62.8  ...  93.0
# 2             1                0.000000         94.0      33  54.9  ...  96.0
# 3             1                0.000000         93.0      74  66.6  ...  93.0
# 4             0                0.000000         93.0     309  57.6  ...  93.0
#
#    Total expenditure  Diphtheria  HIV/AIDS           GDP  Population  \
# 0               8.16        65.0       0.1    584.259210  33736494.0
# 1                NaN        94.0       0.1  13467.123600  43417765.0
# 2                NaN        94.0       0.1    369.654776    291695.0
# 3                NaN        93.0       0.1  56554.387600  23789338.0
# 4                NaN        93.0       0.1  43665.947000   8633169.0
#
#    thinness 1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                 17.2                17.3                            0.479
# 1                  1.0                 0.9                            0.826
# 2                  2.1                 2.2                            0.741
# 3                  0.6                 0.6                            0.937
# 4                  1.9                 2.1                            0.892
#
#    Schooling
# 0       10.1
# 1       17.3
# 2       12.7
# 3       20.4
# 4       15.9
#
# [5 rows x 21 columns]

# %%
sns.pairplot(cleaned_life_expectancy, x_vars = ['Life expectancy'], y_vars = ['percentage expenditure', 'Hepatitis B', 'Measles',
       'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
       'Diphtheria', 'HIV/AIDS', 'GDP', 'Population',
       'thinness 1-19 years', 'thinness 5-9 years',
       'Income composition of resources', 'Schooling'], hue='Status', palette='Dark2')

# %% [markdown]
# **Discussion:** Discuss with your lab partner which factors seem to have a clear correlation with life expectancy.

# %% [markdown]
# Your answer:

# %% [markdown]
# Up to now, we have used single datasets and analyzed them. The WHO dataset contains medical and economic factors, and the plot above showed whether or not there was a correlation between those factors and life expectancy.
#
# Now suppose that a politician approaches you who is interested in whether limiting alcohol consumption might have a positive effect on life expectancy. To analyze this you need to use a second dataset.

# %%
drinks_by_country_loc = os.path.join(os.getcwd(), 'datasets', 'drinks_by_country.csv')
drinks_by_country = pd.read_csv(drinks_by_country_loc)
drinks_by_country.head()
# Out:
#        Country  Beer Servings  Spirit Servings  Wine Servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    Total Litres of Pure Alcohol Continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ## 2.D Combining data from two datasets

# %% [markdown]
# You will rarely find all the information you need in one dataset. Being able to combine data from different datasets into one is very important. Practise it until you feel very comfortable; having just tried it once is not enough.
#
# There a various ways of combining data from datasets: *concatenation*, *merging* and *joining*.

# %% [markdown]
# ### Concatenation
#
# Let's start with the arguably simplest pandas function: `concat`
#
# When you concatenate two *data structures*, pandas DataFrames or pandas series, you simply append one to the other along one axis (along rows or along columns), i.e. you expect that the new data is "independent" of the existing data.
#
# Let's illustrate that on a simple toy example.

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[0, 1, 2, 3])

print(df1)
print('\n\n')
print(df2)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#
#
#
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
result = pd.concat([df1, df2])
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# **Remarks:**
# - Both DataFrames had entries with indices 0-3. However, using `concat` means that there is no relational connection between the rows, and thus `df2` is just appended to `df1`.
# - `pd.concat()` takes as input a list of data structures and can concatenate several DataFrames at once.
#
# As mentioned above, we can specify along which axis the data structures should be concatenated. The default is `axis=0`, as above. We hinted above that `concat` and `join` have two different meanings. In fact, `join={'inner', 'outer'}` is a parameter allowing you to specify the set logic of how data entries that only exist in one set but not the other should be treated. Using *inner* join means that you only want the intersection, while *outer* join means you want to keep the union. Sounds a bit abstract? Let's try it out.

# %%
df3 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])

df4 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7']},
                    index=[0, 1, 2, 3])

print(df3)
print('\n\n')
print(df4)

result = pd.concat([df3, df4], axis=0, join='outer')
result
# Out:
#     A   B   D
# 0  A0  B0  D0
# 1  A1  B1  D1
# 2  A2  B2  D2
# 3  A3  B3  D3
#
#
#
#     A   B   C
# 0  A4  B4  C4
# 1  A5  B5  C5
# 2  A6  B6  C6
# 3  A7  B7  C7
#     A   B    D    C
# 0  A0  B0   D0  NaN
# 1  A1  B1   D1  NaN
# 2  A2  B2   D2  NaN
# 3  A3  B3   D3  NaN
# 0  A4  B4  NaN   C4
# 1  A5  B5  NaN   C5
# 2  A6  B6  NaN   C6
# 3  A7  B7  NaN   C7

# %% [markdown]
# In the example above along `axis=0`, one dataset has the columns 'A', 'B', and 'D', while the other has the columns 'A', 'B', and 'C'. Because we specified `join='outer'` it took the *union* of the two column sets, i.e. 'A', 'B', 'C', and 'D' and just filled out the missing information with `NaN` values. What would happen in the case of `join='inner'`? Give it a try. Is it what you would expect?

# %%
# Your code
result = pd.concat([df3, df4], axis=0, join='inner')
result
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  A4  B4
# 1  A5  B5
# 2  A6  B6
# 3  A7  B7

# %% [markdown]
# Above we have seen, that indices 0-3 were repeated, because we just appended one dataset to the other and didn't assume any relation. However, in that case the indices most probably don't even have a meaning, and could be ignored. This can be achieved with, who could have guessed, `ignore_index=True`.

# %%
result = pd.concat([df1, df2], ignore_index=True)
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# ### Merging
#
# What can we do, when we have a relation between two datasets? For example, in both the life expectancy dataset and the alcohol consumption dataset, we have the column 'Country'. Combining both datasets by comparing those columns and combining the corresponding data entries would be very helpful.
#
# Let's consider a toy example again.

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                     'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']})

right = pd.DataFrame({'key': ['K1', 'K0', 'K3'],
                      'C': ['C0', 'C1', 'C3'],
                      'D': ['D0', 'D1', 'D3']})
print(left)
print('\n\n')
print(right)
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
#
#
#
#   key   C   D
# 0  K1  C0  D0
# 1  K0  C1  D1
# 2  K3  C3  D3

# %%
result = pd.merge(left, right, on='key')
result
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C1  D1
# 1  K1  A1  B1  C0  D0

# %% [markdown]
# With `on='column'` we specify the column the two datasets will be compared on.
#
# **Remarks**
# - In contrast to `pd.concat()`, `pd.merge()` only takes two DataFrames as input (left and right)
# - `pd.merge()` compares the rows across all data entries. For example, in the 'right' dataset the data entry 'K0' is in the second row though in the left data set it is in the first row.
# - As you can see above, by default, `pd.merge()` uses an inner join.
# - The column specified by the keyword 'on' needs to be *written the same way* in both datasets.
#
# With `pd.concat()` the 'join' parameter specifies an inner join and an outer join. With `pd.merge()` we have the same option, only the keyword is `how={'inner', 'outer', 'left', 'right'}`, with the two extra options `left` and `right`. Technically `left` stands for 'left outer join', and means that:
# - we keep all rows that appear in the left dataset
# - merge the matching rows from the right dataset into the left dataset
# - drop all rows that only appear in the right dataset.
#
# Let's try it out.

# %%
result = pd.merge(left, right, on='key', how='left')
result
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C1   D1
# 1  K1  A1  B1   C0   D0
# 2  K2  A2  B2  NaN  NaN

# %% [markdown]
# 'K0', 'K1', and 'K2' are kept, as they all appear in the `left` dataset. However, 'K3', which only appears in the right dataset is dropped.
#
# **Note on performance**: By default, `merge` will sort the output based on the values in the key column in lexicographic order, which can affect the performance substantially, if you do not care about the order, you can set `sort=False`.
#
# There are a couple of more parameters you can set, in both `concat` and `merge`. However, the above are the most important. If you are interested, check out the [pandas website](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html).
#
# **Exercise 06:** Use either `pd.merge` or `pd.concat` to combine the two datasets(`cleaned_life_expectancy`, `drinks_by_country`) so we can relate drinks consumption to life expectancy. We don't want to have unnecessary NaN values, so only keep the entries that are found in both datasets. Save the result to `final_life_expectancy`.

# %%
# Your code
final_life_expectancy = pd.merge(drinks_by_country, cleaned_life_expectancy, how='inner')
final_life_expectancy
# Out:
#         Country  Beer Servings  Spirit Servings  Wine Servings  \
# 0   Afghanistan              0                0              0
# 1     Argentina            193               25            221
# 2       Armenia             21              179             11
# 3     Australia            261               72            212
# 4       Austria            279               75            191
# ..          ...            ...              ...            ...
# 92      Uruguay            115               35            220
# 93   Uzbekistan             25              101              8
# 94      Vanuatu             21               18             11
# 95        Yemen              6                0              0
# 96       Zambia             32               19              4
#
#     Total Litres of Pure Alcohol      Continent  Year      Status  \
# 0                            0.0           Asia  2015  Developing
# 1                            8.3  South America  2015  Developing
# 2                            3.8         Europe  2015  Developing
# 3                           10.4        Oceania  2015   Developed
# 4                            9.7         Europe  2015   Developed
# ..                           ...            ...   ...         ...
# 92                           6.6  South America  2015  Developing
# 93                           2.4           Asia  2015  Developing
# 94                           0.9        Oceania  2015  Developing
# 95                           0.1           Asia  2015  Developing
# 96                           2.5         Africa  2015  Developing
#
#     Life expectancy  Adult Mortality  ... Polio  Total expenditure  \
# 0              65.0            263.0  ...   6.0               8.16
# 1              76.3            116.0  ...  93.0                NaN
# 2              74.8            118.0  ...  96.0                NaN
# 3              82.8             59.0  ...  93.0                NaN
# 4              81.5             65.0  ...  93.0                NaN
# ..              ...              ...  ...   ...                ...
# 92             77.0            116.0  ...  95.0                NaN
# 93             69.4            184.0  ...  99.0                NaN
# 94             72.0             13.0  ...  65.0                NaN
# 95             65.7            224.0  ...  63.0                NaN
# 96             61.8             33.0  ...   9.0                NaN
#
#     Diphtheria HIV/AIDS           GDP  Population  thinness 1-19 years  \
# 0         65.0      0.1    584.259210  33736494.0                 17.2
# 1         94.0      0.1  13467.123600  43417765.0                  1.0
# 2         94.0      0.1    369.654776    291695.0                  2.1
# 3         93.0      0.1  56554.387600  23789338.0                  0.6
# 4         93.0      0.1  43665.947000   8633169.0                  1.9
# ..         ...      ...           ...         ...                  ...
# 92        95.0      0.1  15524.842470   3431552.0                  1.5
# 93        99.0      0.1   2137.576852    312989.0                  3.0
# 94        64.0      0.1    285.834140     26463.0                  1.5
# 95        69.0      0.1           NaN         NaN                 13.6
# 96         9.0      4.1   1313.889646    161587.0                  6.3
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                  0.9                            0.826       17.3
# 2                  2.2                            0.741       12.7
# 3                  0.6                            0.937       20.4
# 4                  2.1                            0.892       15.9
# ..                 ...                              ...        ...
# 92                 1.4                            0.794       15.5
# 93                 3.1                            0.697       12.1
# 94                 1.4                            0.598       10.8
# 95                13.4                            0.499        9.0
# 96                 6.1                            0.576       12.5
#
# [97 rows x 26 columns]

# %% [markdown]
# Again, ignore the code below. Just run it and compare the impact of different drinks on life expectancy.

# %%
sns.pairplot(final_life_expectancy, x_vars = ['Life expectancy'], y_vars = ['Beer Servings', 'Spirit Servings', 'Wine Servings', 'Total Litres of Pure Alcohol'], hue='Status', palette='Dark2')

# %% [markdown]
# **Discussion:**
# - Does the data above suggest that alcohol consumption as an average for a population has an impact on life expectancy?
# - Find the three countries with the lowest life expectancy from `final_life_expectancy`.
# - Have a look at the plots above, and discuss with your lab partner: Can we pinpoint the short life expectancy to specific factors? What changes would help those countries probably most to improve their life expectancy.

# %%
# Your code

# %% [markdown]
# Your answer:
